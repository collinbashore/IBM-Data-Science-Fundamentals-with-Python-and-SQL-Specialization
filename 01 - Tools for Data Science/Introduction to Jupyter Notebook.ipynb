# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### **Collin Bashore**
#
# Data Science Student

# %% [markdown]
# *I am interested in Data Science because I am interested in learning various computational tools and algorithms used in Data Science to improve our daily lifes. I would like to utilize my academic background and knowledge in Chemistry, Materials Science & Engineering (MSE), Business, and Mathematics in my career as a Data Professional to analyze and automate (big) data in the Chemical Industry or any Materials Science-based industries such as Semiconductor Industry. I am also interested in learning how to learn how to use different technologies such as sensors and Internet of Things (IoT) devices.*

# %% [markdown]
# ### This code below calculates the following formula

# %%
x = (2+6)**2/(8-4)
x
# Out:
# 16.0

# %% [markdown]
# - ~~ tomato is a fruit ~~
# - avocado is a fruit??
#
# Fruits I love to eat
# 1. Strawberries
# 2. Blueberries
# 3. Bananas
# 4. Avocadoes
# 5. Raspberries
#
#
# | Fruit     | Color |
# | --------- | ----- |
# | Strawberry| Red   |
# | Blueberry | Blue  |
# | Banana    | Yellow|
# | Avocado   | Green |
# | Raspberry | Magenta|
