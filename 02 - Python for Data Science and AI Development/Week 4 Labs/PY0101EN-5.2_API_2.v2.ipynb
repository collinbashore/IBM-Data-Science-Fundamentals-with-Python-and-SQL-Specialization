# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# # Simple APIs
#
# ## Random User and Fruitvice API Examples
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#
# *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more\
#     productive.
# *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#     independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#
# *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data\
#     breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
#
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# *   get_cell()
# *   get_city()
# *   get_dob()
# *   get_email()
# *   get_first_name()
# *   get_full_name()
# *   get_gender()
# *   get_id()
# *   get_id_number()
# *   get_id_type()
# *   get_info()
# *   get_last_name()
# *   get_login_md5()
# *   get_login_salt()
# *   get_login_sha1()
# *   get_login_sha256()
# *   get_nat()
# *   get_password()
# *   get_phone()
# *   get_picture()
# *   get_postcode()
# *   get_registered()
# *   get_state()
# *   get_street()
# *   get_username()
# *   get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=7dc07f7749039a70d5490c0c44acc33f4d96a67a7446d805063a57841c31984f
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f8/a9/23/1df3ef7a5177d99b4cba8fa52415e1360bde68f520c2a0e489
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f6e8f4bfc90>,
#  <randomuser.RandomUser at 0x7f6e8f4bfcd0>,
#  <randomuser.RandomUser at 0x7f6e8f4bfd10>,
#  <randomuser.RandomUser at 0x7f6e8f4bfd50>,
#  <randomuser.RandomUser at 0x7f6e8f4bfd90>,
#  <randomuser.RandomUser at 0x7f6e8f4bfe10>,
#  <randomuser.RandomUser at 0x7f6e8f4bfe50>,
#  <randomuser.RandomUser at 0x7f6e8f4bfe90>,
#  <randomuser.RandomUser at 0x7f6e8f4bfed0>,
#  <randomuser.RandomUser at 0x7f6e8f4bfdd0>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Ronnie Fields   ronnie.fields@example.com
# Ian Hawkins   ian.hawkins@example.com
# عرشيا حیدری   aarshy.hydry@example.com
# Valtteri Koski   valtteri.koski@example.com
# Alfredo Santiago   alfredo.santiago@example.com
# Louise Petit   louise.petit@example.com
# کیمیا موسوی   khymy.mwswy@example.com
# Greg Hawkins   greg.hawkins@example.com
# آرش علیزاده   arsh.aalyzdh@example.com
# Akseli Tuominen   akseli.tuominen@example.com

# %% [markdown]
# ## Exercise 1
#
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
rand_photos = r.generate_users(5)

for photo in rand_photos:
    print(photo.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/28.jpg
# https://randomuser.me/api/portraits/men/13.jpg
# https://randomuser.me/api/portraits/men/60.jpg
# https://randomuser.me/api/portraits/women/57.jpg
# https://randomuser.me/api/portraits/men/24.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                    Name  Gender                 City               State  \
# 0          Eloane Blanc  female                Tours      Saône-et-Loire
# 1           Zoé Rolland  female             Nanterre         Deux-Sèvres
# 2        Adriana Bonten  female            Heenvliet          Gelderland
# 3       Bérénice Dupuis  female         Saint-Pierre        Eure-et-Loir
# 4          Suzana Viana  female  Valparaíso de Goiás    Distrito Federal
# 5        Amandine Leroy  female              Créteil               Indre
# 6        محمدطاها جعفری    male            خمینی‌شهر              اردبیل
# 7           Ana Fuentes  female               Orense  Castilla la Mancha
# 8  Melquisedeque Moraes    male       Belo Horizonte               Bahia
# 9            Karl Vidal    male                Augst                Jura
#
#                               Email                       DOB  \
# 0          eloane.blanc@example.com  1956-03-22T22:26:29.611Z
# 1           zoe.rolland@example.com  1998-01-15T04:59:59.728Z
# 2        adriana.bonten@example.com  1958-02-04T06:04:20.282Z
# 3       berenice.dupuis@example.com  1950-06-25T18:02:24.770Z
# 4          suzana.viana@example.com  1955-01-28T16:58:56.521Z
# 5        amandine.leroy@example.com  1964-07-15T17:53:53.550Z
# 6         mhmdth.jaafry@example.com  1957-02-05T09:05:13.729Z
# 7           ana.fuentes@example.com  1957-09-23T08:26:06.899Z
# 8  melquisedeque.moraes@example.com  1989-07-26T15:04:14.127Z
# 9            karl.vidal@example.com  1974-02-13T16:15:48.798Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/91.jpg
# 1  https://randomuser.me/api/portraits/women/83.jpg
# 2  https://randomuser.me/api/portraits/women/84.jpg
# 3  https://randomuser.me/api/portraits/women/75.jpg
# 4   https://randomuser.me/api/portraits/women/0.jpg
# 5  https://randomuser.me/api/portraits/women/37.jpg
# 6    https://randomuser.me/api/portraits/men/76.jpg
# 7  https://randomuser.me/api/portraits/women/76.jpg
# 8    https://randomuser.me/api/portraits/men/73.jpg
# 9    https://randomuser.me/api/portraits/men/20.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 8   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 9   {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 10  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 11  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 12  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 29  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 30  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 31  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 32  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 33  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 34  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 35  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 36  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 37  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 38  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                       9.00                9.00            1.50
# 8                      27.10                1.50            5.30
# 9                       8.00                0.60            0.40
# 10                     19.00                0.80            0.30
# 11                     10.00                0.90            0.60
# 12                     18.10                0.72            0.16
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                     15.00                0.40            0.10
# 29                     18.00                0.00            0.00
# 30                     13.12                0.54            0.12
# 31                      7.00                1.00            0.40
# 32                     11.40                0.70            0.28
# 33                     18.70                1.70            1.20
# 34                     12.00                1.20            0.70
# 35                      5.50                0.80            0.40
# 36                      8.30                0.00            0.40
# 37                      3.90                0.90            0.20
# 38                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    60              8.00
# 8                   147              6.75
# 9                    44              3.00
# 10                   74             16.00
# 11                   44              0.00
# 12                   69             16.00
# 13                   69             15.48
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   57             10.00
# 29                   81             18.00
# 30                   50              9.85
# 31                   36              3.00
# 32                   46              9.92
# 33                   83             13.70
# 34                   53              4.40
# 35                   29              5.40
# 36                   45              9.10
# 37                   74              2.60
# 38                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
#
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2["name"] == 'Banana']
print(banana.iloc[0]['nutritions.calories'])
# Out:
# 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
#
# 1.  Using `requests.get("url")` function, load your data.

# %%
# Write your code here

# Load/extract API from the ZenQuotes wesite

quotes_data = requests.get("https://zenquotes.io/api/quotes")

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2.  Retrieve results using `json.loads()` function.

# %%
# Write your code here
load_quotes_data = json.loads(quotes_data.text)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3.  Convert json data into *pandas* data frame.

# %%
# Write your code here
pd.DataFrame(load_quotes_data)

# q = quote text
# a = author name
# c = character count
# h = pre-formatted HTML quote
# Out:
#                                                     q                      a  \
# 0   When you want to be honored by others, you lea...        Sathya Sai Baba
# 1   There is no right or wrong, only a series of p...          Deepak Chopra
# 2   The more acquaintances you have, the less you ...        Chinese Proverb
# 3   The older you get, the better you get. Unless ...            Betty White
# 4   I begin with an idea and then it becomes somet...          Pablo Picasso
# 5    Wherever you are, it's the place you need to be.          Maxime Lagace
# 6                   The Art of Peace begins with you.        Morihei Ueshiba
# 7   Life is much like going to the gym. The most p...        Robert Kiyosaki
# 8   If you do the work you get rewarded. There are...         Michael Jordan
# 9       We ordinary people must forge our own beauty.         Kenji Miyazawa
# 10  Every man desires to live long, but no man wis...         Jonathan Swift
# 11  Values are like fingerprints. Nobody's are the...          Elvis Presley
# 12  If you are depressed, you are living in the pa...                Lao Tzu
# 13  We have more possibilities available in each m...        Thich Nhat Hanh
# 14  My mind seems to have become a kind of machine...         Charles Darwin
# 15                        Confidence breeds beauty.             Estee Lauder
# 16  Blessed is he who expects nothing, for he shal...         Alexander Pope
# 17  Coming together is a beginning, staying togeth...             Henry Ford
# 18  Having lots of money while not having inner pe...  Paramahansa Yogananda
# 19  You Create Your Own Present By What You Give Y...        Spencer Johnson
# 20                   Whatever you are, be a good one.        Abraham Lincoln
# 21  Surround yourself only with people who are goi...          Oprah Winfrey
# 22  Enjoy every minute of life. Never second-guess...         Michael Jordan
# 23  It is well known that those who do not trust t...           Alfred Adler
# 24  The more you feed your mind with positive thou...         Roy T. Bennett
# 25  Human beings believe just as they breathe - in...      Carlos Ruiz Zafon
# 26  The only way to 'find out if it will work out'...            Simon Sinek
# 27  Trust, like the soul, never returns once it is...        Publilius Syrus
# 28  You may be one person in this world, but to on...                Unknown
# 29  Where we fall are the stepping-stones for our ...           Lolly Daskal
# 30  At every moment where language can't go, that'...            Bodhidharma
# 31                    Make each day your masterpiece.            John Wooden
# 32  No matter how smart we may think we are, no ma...         Kamal Ravikant
# 33                            Hope is a waking dream.              Aristotle
# 34  I do not exist to impress the world. I exist t...           Richard Bach
# 35  Fear is your worst enemy. Risk is your best fr...        Gurbaksh Chahal
# 36  People rarely succeed unless they have fun in ...          Dale Carnegie
# 37  If we all did the things we are capable of doi...          Thomas Edison
# 38  All things come into being by conflict of oppo...             Heraclitus
# 39  Do not take life too seriously. You will never...         Elbert Hubbard
# 40  I no doubt deserved my enemies, but I don't be...           Walt Whitman
# 41  I never dwell on what happened. You can't chan...            Joan Rivers
# 42  There are two kinds of perfect people: those w...        Chinese Proverb
# 43         Sadness is but a wall between two gardens.          Kahlil Gibran
# 44  The beautiful journey of today can only begin ...         Steve Maraboli
# 45  I would rather die on my feet than live on my ...              Euripides
# 46  The successful warrior is the average man, wit...              Bruce Lee
# 47  Nature is pleased with simplicity. And nature ...           Isaac Newton
# 48       Be yourself; everyone else is already taken.            Oscar Wilde
# 49     Great minds are always feared by lesser minds.              Dan Brown
#
#       c                                                  h
# 0    69  <blockquote>&ldquo;When you want to be honored...
# 1   129  <blockquote>&ldquo;There is no right or wrong,...
# 2    56  <blockquote>&ldquo;The more acquaintances you ...
# 3    62  <blockquote>&ldquo;The older you get, the bett...
# 4    56  <blockquote>&ldquo;I begin with an idea and th...
# 5    48  <blockquote>&ldquo;Wherever you are, it's the ...
# 6    33  <blockquote>&ldquo;The Art of Peace begins wit...
# 7   111  <blockquote>&ldquo;Life is much like going to ...
# 8    68  <blockquote>&ldquo;If you do the work you get ...
# 9    45  <blockquote>&ldquo;We ordinary people must for...
# 10   60  <blockquote>&ldquo;Every man desires to live l...
# 11   98  <blockquote>&ldquo;Values are like fingerprint...
# 12  151  <blockquote>&ldquo;If you are depressed, you a...
# 13   68  <blockquote>&ldquo;We have more possibilities ...
# 14  107  <blockquote>&ldquo;My mind seems to have becom...
# 15   27  <blockquote>&ldquo;Confidence breeds beauty.  ...
# 16   70  <blockquote>&ldquo;Blessed is he who expects n...
# 17   95  <blockquote>&ldquo;Coming together is a beginn...
# 18  101  <blockquote>&ldquo;Having lots of money while ...
# 19   69  <blockquote>&ldquo;You Create Your Own Present...
# 20   32  <blockquote>&ldquo;Whatever you are, be a good...
# 21   68  <blockquote>&ldquo;Surround yourself only with...
# 22   52  <blockquote>&ldquo;Enjoy every minute of life....
# 23   75  <blockquote>&ldquo;It is well known that those...
# 24  105  <blockquote>&ldquo;The more you feed your mind...
# 25   64  <blockquote>&ldquo;Human beings believe just a...
# 26   59  <blockquote>&ldquo;The only way to 'find out i...
# 27   52  <blockquote>&ldquo;Trust, like the soul, never...
# 28   78  <blockquote>&ldquo;You may be one person in th...
# 29   54  <blockquote>&ldquo;Where we fall are the stepp...
# 30   58  <blockquote>&ldquo;At every moment where langu...
# 31   31  <blockquote>&ldquo;Make each day your masterpi...
# 32  106  <blockquote>&ldquo;No matter how smart we may ...
# 33   23  <blockquote>&ldquo;Hope is a waking dream.&rdq...
# 34   94  <blockquote>&ldquo;I do not exist to impress t...
# 35   51  <blockquote>&ldquo;Fear is your worst enemy. R...
# 36   66  <blockquote>&ldquo;People rarely succeed unles...
# 37   87  <blockquote>&ldquo;If we all did the things we...
# 38   52  <blockquote>&ldquo;All things come into being ...
# 39   67  <blockquote>&ldquo;Do not take life too seriou...
# 40   74  <blockquote>&ldquo;I no doubt deserved my enem...
# 41   66  <blockquote>&ldquo;I never dwell on what happe...
# 42   96  <blockquote>&ldquo;There are two kinds of perf...
# 43   42  <blockquote>&ldquo;Sadness is but a wall betwe...
# 44   83  <blockquote>&ldquo;The beautiful journey of to...
# 45   52  <blockquote>&ldquo;I would rather die on my fe...
# 46   65  <blockquote>&ldquo;The successful warrior is t...
# 47   58  <blockquote>&ldquo;Nature is pleased with simp...
# 48   44  <blockquote>&ldquo;Be yourself; everyone else ...
# 49   46  <blockquote>&ldquo;Great minds are always fear...

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
#
# [Svitlana Kramar](https://www.linkedin.com/in/svitlana-kramar?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2022-01-01)
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
# Copyright © 2020 IBM Corporation. All rights reserved.
